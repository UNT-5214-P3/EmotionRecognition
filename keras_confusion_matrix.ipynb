# %% [markdown]
# # Confusion Matrix for Convolutional Neural Network Model (keras)
#
# ** Code obtained from https://github.com/gitshanks/fer2013

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
# %matplotlib inline

# %%
y_true = np.load('data/truey.npy')
y_pred = np.load('data/predy.npy')
cm = confusion_matrix(y_true, y_pred)
labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']
title='Confusion matrix'
print(cm)
# Out:
# [[291   6  49  22  72   9  49]
#  [ 11  33   3   2   2   1   0]
#  [ 47   7 283  21  95  45  47]
#  [ 22   0  18 751  30  14  46]
#  [ 59   1  69  29 346   1  83]
#  [ 11   0  54  31   4 301  13]
#  [ 39   1  37  51  95  11 377]]

# %%
plt.figure(figsize=(15,7))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title(title)
plt.colorbar()
tick_marks = np.arange(len(labels))
plt.xticks(tick_marks, labels, rotation=45)
plt.yticks(tick_marks, labels)
fmt = 'd'
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], fmt),
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.tight_layout()
plt.show()
